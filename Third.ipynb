# %%
# %pip install numpy
# %pip install pandas
# %pip install seaborn
# %pip install matplotlib
# %pip install scikit-learn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
data = pd.read_csv('Advertising.csv', index_col=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr_model = LinearRegression()
y=data['sales']
x=data.drop(columns=['sales'])
lr_model.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred=lr_model.predict(x)
data['y_pred']=y_pred
# Out:
#         TV  radio  newspaper  sales     y_pred
# 1    230.1   37.8       69.2   22.1  20.523974
# 2     44.5   39.3       45.1   10.4  12.337855
# 3     17.2   45.9       69.3    9.3  12.307671
# 4    151.5   41.3       58.5   18.5  17.597830
# 5    180.8   10.8       58.4   12.9  13.188672
# ..     ...    ...        ...    ...        ...
# 196   38.2    3.7       13.8    7.6   5.370342
# 197   94.2    4.9        8.1    9.7   8.165312
# 198  177.0    9.3        6.4   12.8  12.785921
# 199  283.6   42.0       66.2   25.5  23.767321
# 200  232.1    8.6        8.7   13.4  15.173196
#
# [200 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
plt.scatter(data['TV'],data['sales'], label='Actual Value')
plt.plot(data['TV'], data['y_pred'], color='red', label='Best Fit Line')
plt.legend()

# %%
plt.scatter(data['radio'],data['sales'], label='Actual Value')
# plt.plot(data['radio'], data['y_pred'], color='red', label='Best Fit Line')
plt.legend()

# %%
plt.scatter(data['newspaper'],data['sales'], label='Actual Value')
# plt.plot(data['radio'], data['y_pred'], color='red', label='Best Fit Line')
plt.legend()
